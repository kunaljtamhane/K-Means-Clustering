# %% [markdown]
# ### Problem Statement
# You are the owner of a large store and you have historical data about customers and purchase such as age, gender, annual income and spending score. Spending score is something you have assigned to each customer based on certain purchase related parameters (not part of this dataset).
# You would like to find out clusters or groups of patterns among the customers so that you can run targeted campaigns to promote your merchendise

# %% [markdown]
# ## K mean Clustering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os 
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
df = pd.read_csv('Mall_Customers.csv')
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %% [markdown]
# ## Data Exploration and Visualization

# %% [markdown]
# ### Plot pairwise relationship between features in a dataset

# %%
plt.figure(1,figsize=(16,10))
sns.pairplot(data=df, hue='Gender')
plt.show()

# %% [markdown]
# ### Distribution of Gender in the Data

# %%
plt.figure(1, figsize=(4,4))
sns.countplot(x='Gender', data=df)
plt.show()

# %% [markdown]
# ### Transform Gender to 0's and 1's

# %%
df['Gender'] = df['Gender'].map({'Male':1, 'Female':0})

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1       1   19                  15                      39
# 1             2       1   21                  15                      81
# 2             3       0   20                  16                       6
# 3             4       0   23                  16                      77
# 4             5       0   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196       0   35                 120                      79
# 196         197       0   45                 126                      28
# 197         198       1   32                 126                      74
# 198         199       1   32                 137                      18
# 199         200       1   30                 137                      83
#
# [200 rows x 5 columns]

# %%
plt.figure(1, figsize=(16,4))
n = 0 
for x in ['Age', 'Annual Income (k$)', 'Spending Score (1-100)']:
    n += 1
    plt.subplot(1, 3, n)
    plt.subplots_adjust(hspace=0.5 , wspace=0.5)
    sns.distplot(df[x] , bins=10)
    plt.title('Distplot of {}'.format(x))
plt.show()

# %% [markdown]
# ## Building our K-Means Model

# %%
X = df.iloc[:, -4:]
X
# Out:
#      Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0         1   19                  15                      39
# 1         1   21                  15                      81
# 2         0   20                  16                       6
# 3         0   23                  16                      77
# 4         0   31                  17                      40
# ..      ...  ...                 ...                     ...
# 195       0   35                 120                      79
# 196       0   45                 126                      28
# 197       1   32                 126                      74
# 198       1   32                 137                      18
# 199       1   30                 137                      83
#
# [200 rows x 4 columns]

# %% [markdown]
# ### we will create K means models iteratively between k values of 3 to 10 and at each step, capture the Silhoutte score and intertia (sum of squared distances)

# %%
km_inertias, km_scores = [], []

for k in range(3, 10):
    km = KMeans(n_clusters=k).fit(X)
    km_inertias.append(km.inertia_)
    km_scores.append(silhouette_score(X, km.labels_))
    print(f"Processing K-Means with k = {k}, Intertia = {km.inertia_}, Silhoutte Score = {silhouette_score(X, km.labels_)}")
# Out:
# Processing K-Means with k = 3, Intertia = 143391.59236035676, Silhoutte Score = 0.383798873822341
# Processing K-Means with k = 4, Intertia = 104414.67534220166, Silhoutte Score = 0.4052954330641215
# Processing K-Means with k = 5, Intertia = 75427.71182424155, Silhoutte Score = 0.44424291275274114
# Processing K-Means with k = 6, Intertia = 58348.64136331505, Silhoutte Score = 0.45205475380756527
# Processing K-Means with k = 7, Intertia = 51165.184237107926, Silhoutte Score = 0.43946743327036053
# Processing K-Means with k = 8, Intertia = 44359.634641148325, Silhoutte Score = 0.4294563708430266
# Processing K-Means with k = 9, Intertia = 40674.154550504914, Silhoutte Score = 0.41273936332819244

# %% [markdown]
# ## Elbow method to find Optimum k

# %%
sns.lineplot(range(3, 10), km_inertias)
plt.title('elbow graph / inertia depending on k')
plt.show()

# %% [markdown]
# ## Silhoutte Method for optimum k

# %%
sns.lineplot(range(3, 10), km_scores)
plt.title('scores depending on k')
plt.show()

# %%
km = KMeans(n_clusters=6).fit(X)

# %%
X
# Out:
#      Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0         1   19                  15                      39
# 1         1   21                  15                      81
# 2         0   20                  16                       6
# 3         0   23                  16                      77
# 4         0   31                  17                      40
# ..      ...  ...                 ...                     ...
# 195       0   35                 120                      79
# 196       0   45                 126                      28
# 197       1   32                 126                      74
# 198       1   32                 137                      18
# 199       1   30                 137                      83
#
# [200 rows x 4 columns]

# %% [markdown]
# ### Assign the Cluster Labels the Data

# %%
X['Label'] = km.labels_
X
# Out:
#      Gender  Age  Annual Income (k$)  Spending Score (1-100)  Label
# 0         1   19                  15                      39      4
# 1         1   21                  15                      81      3
# 2         0   20                  16                       6      4
# 3         0   23                  16                      77      3
# 4         0   31                  17                      40      4
# ..      ...  ...                 ...                     ...    ...
# 195       0   35                 120                      79      1
# 196       0   45                 126                      28      5
# 197       1   32                 126                      74      1
# 198       1   32                 137                      18      5
# 199       1   30                 137                      83      1
#
# [200 rows x 5 columns]

# %%
X['Label'].unique()
# Out:
# array([4, 3, 0, 2, 1, 5], dtype=int32)

# %%
X.Label.value_counts()
# Out:
# 0    45
# 1    39
# 2    38
# 5    35
# 3    22
# 4    21
# Name: Label, dtype: int64

# %%
pivot = X.pivot_table(values=['Annual Income (k$)', 'Spending Score (1-100)', 'Age'], index=['Label'], aggfunc=np.mean)
pivot
# Out:
#              Age  Annual Income (k$)  Spending Score (1-100)
# Label
# 0      56.155556           53.377778               49.088889
# 1      32.692308           86.538462               82.128205
# 2      27.000000           56.657895               49.131579
# 3      25.272727           25.727273               79.363636
# 4      44.142857           25.142857               19.523810
# 5      41.685714           88.228571               17.285714

# %% [markdown]
# ## Visualization of the Cluster in a 3D scatter plot

# %%
X
# Out:
#      Gender  Age  Annual Income (k$)  Spending Score (1-100)  Label
# 0         1   19                  15                      39      4
# 1         1   21                  15                      81      3
# 2         0   20                  16                       6      4
# 3         0   23                  16                      77      3
# 4         0   31                  17                      40      4
# ..      ...  ...                 ...                     ...    ...
# 195       0   35                 120                      79      1
# 196       0   45                 126                      28      5
# 197       1   32                 126                      74      1
# 198       1   32                 137                      18      5
# 199       1   30                 137                      83      1
#
# [200 rows x 5 columns]

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(12,8))
ax = Axes3D(fig)

xs = X['Age']
ys = X['Annual Income (k$)']
zs = X['Spending Score (1-100)']
im = ax.scatter(xs, ys, zs, s=50, alpha=0.6, c=km.labels_, cmap='RdYlGn')
fig.colorbar(im, ax=ax)
ax.set_xlabel('Age')
ax.set_ylabel('Annual income')
ax.set_zlabel('Spending score')

plt.show()

# %% [markdown]
# ## Analysing Each cluster a bit more

# %%
X.Label.value_counts()
# Out:
# 0    45
# 1    39
# 2    38
# 5    35
# 3    22
# 4    21
# Name: Label, dtype: int64

# %%
for k in range(6):
    print(f'Cluster nb: {k}')
    print(X[X.Label == k].describe().iloc[:, 1:-1])
    print('\n\n')
# Out:
# Cluster nb: 0
#              Age  Annual Income (k$)  Spending Score (1-100)
# count  45.000000           45.000000               45.000000
# mean   56.155556           53.377778               49.088889
# std     8.543886            8.435016                6.251626
# min    43.000000           38.000000               35.000000
# 25%    49.000000           47.000000               45.000000
# 50%    54.000000           54.000000               49.000000
# 75%    65.000000           62.000000               55.000000
# max    70.000000           67.000000               60.000000
#
#
#
# Cluster nb: 1
#              Age  Annual Income (k$)  Spending Score (1-100)
# count  39.000000           39.000000               39.000000
# mean   32.692308           86.538462               82.128205
# std     3.728650           16.312485                9.364489
# min    27.000000           69.000000               63.000000
# 25%    30.000000           75.500000               74.500000
# 50%    32.000000           79.000000               83.000000
# 75%    35.500000           95.000000               90.000000
# max    40.000000          137.000000               97.000000
#
#
#
# Cluster nb: 2
#              Age  Annual Income (k$)  Spending Score (1-100)
# count  38.000000           38.000000               38.000000
# mean   27.000000           56.657895               49.131579
# std     7.032742            9.905708                7.853975
# min    18.000000           39.000000               29.000000
# 25%    21.000000           48.000000               42.000000
# 50%    26.500000           59.500000               50.000000
# 75%    31.750000           63.750000               55.000000
# max    40.000000           76.000000               61.000000
#
#
#
# Cluster nb: 3
#              Age  Annual Income (k$)  Spending Score (1-100)
# count  22.000000           22.000000               22.000000
# mean   25.272727           25.727273               79.363636
# std     5.257030            7.566731               10.504174
# min    18.000000           15.000000               61.000000
# 25%    21.250000           19.250000               73.000000
# 50%    23.500000           24.500000               77.000000
# 75%    29.750000           32.250000               85.750000
# max    35.000000           39.000000               99.000000
#
#
#
# Cluster nb: 4
#              Age  Annual Income (k$)  Spending Score (1-100)
# count  21.000000           21.000000               21.000000
# mean   44.142857           25.142857               19.523810
# std    13.089254            7.226934               12.769569
# min    19.000000           15.000000                3.000000
# 25%    35.000000           19.000000                6.000000
# 50%    45.000000           24.000000               15.000000
# 75%    53.000000           30.000000               31.000000
# max    67.000000           39.000000               40.000000
#
#
#
# Cluster nb: 5
#              Age  Annual Income (k$)  Spending Score (1-100)
# count  35.000000           35.000000               35.000000
# mean   41.685714           88.228571               17.285714
# std    10.897305           16.367266               10.211215
# min    19.000000           71.000000                1.000000
# 25%    35.000000           77.500000               10.000000
# 50%    43.000000           85.000000               16.000000
# 75%    47.500000           97.500000               23.500000
# max    59.000000          137.000000               39.000000
